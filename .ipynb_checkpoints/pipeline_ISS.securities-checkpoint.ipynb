# %%
import pandas as pd
import datetime
import random

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
from ISS.securities import q, security_description, security_boards, security_indices, security_aggregates, security_bondyields

# %%
securityids = ['MOEX', 'SBER', 'AFKS', 'SU25081RMFS9']
dt = datetime.date(2017, 9, 11)

# %%
s = q(random.choice(securityids))
s.head()
# Out:
#        id        secid   shortname regnumber                     name  isin  is_traded  emitent_id emitent_title emitent_inn emitent_okpo gosreg         type        group primary_boardid marketprice_boardid
# 0   76098     MOEXREPO      MXREPO      None       MOEXREPO обл 12:30  None          1         NaN          None        None         None   None  stock_index  stock_index            SNDX                None
# 1   76100   MOEXREPOEQ    MXREPOEQ      None       MOEXREPO акц 12:30  None          1         NaN          None        None         None   None  stock_index  stock_index            SNDX                None
# 2   76099    MOEXREPOE     MXREPOE      None       MOEXREPO обл 19:00  None          1         NaN          None        None         None   None  stock_index  stock_index            SNDX                None
# 3  105464   MOEXREPO1W  MOEXREPO1W      None  MOEXREPO 1 неделя 12:30  None          1         NaN          None        None         None   None  stock_index  stock_index            SNDX                None
# 4   76101  MOEXREPOEQE   MXREPOEQE      None       MOEXREPO акц 19:00  None          1         NaN          None        None         None   None  stock_index  stock_index            SNDX                None

# %%
d = security_description(random.choice(securityids))
d.head()
# Out:
#         name                              title                   value    type  sort_order  is_hidden  precision
# 0      SECID                  Код ценной бумаги                    SBER  string           1          0        NaN
# 1       NAME                Полное наименование  Сбербанк России ПАО ао  string           2          0        NaN
# 2  SHORTNAME               Краткое наименование                Сбербанк  string           3          0        NaN
# 3       ISIN                           ISIN код            RU0009029540  string           4          0        NaN
# 4  REGNUMBER  Номер государственной регистрации               10301481B  string           5          0        NaN

# %%
b = security_boards(random.choice(securityids))
b.head()
# Out:
#   secid boardid                           title  board_group_id  market_id  market  engine_id engine  is_traded  decimals history_from history_till listed_from listed_till  is_primary
# 0  SBER    TQBR                   Т+ Акции и ДР              57          1  shares          1  stock          1         2   2013-03-25   2017-09-12  2013-03-25  2017-09-13           1
# 1  SBER    EQBR  Основной режим: А1-Акции и паи               6          1  shares          1  stock          0         2   2011-11-21   2013-08-30  2011-11-21  2013-08-30           0
# 2  SBER    SOTC              Внебиржевые сделки              71         29     otc          1  stock          1         5   2014-02-24   2017-09-12  2009-09-01  2017-09-13           0
# 3  SBER    SMAL        Т+ Неполные лоты (акции)              21          1  shares          1  stock          1         2   2011-11-21   2017-09-12  2011-11-21  2017-09-13           0
# 4  SBER    EQDP          Крупные пакеты - Акции              42          1  shares          1  stock          1         2   2011-12-12   2017-09-12  2011-12-12  2017-09-13           0

# %%
i = security_indices(random.choice(securityids))
i.head()
# Out:
#           SECID         SHORTNAME        FROM        TILL
# 0      MICEXBMI     Широкий рынок  2011-12-30  2017-09-12
# 1      MICEXFNL           Финансы  2013-06-18  2017-09-12
# 2  MICEXINDEXCF       Индекс ММВБ  2012-09-18  2017-09-12
# 3       MICEXMC          MICEX MC  2011-11-21  2015-03-01
# 4      MICEXTLC  Телекоммуникации  2011-11-21  2013-06-17

# %%
a = security_aggregates(random.choice(securityids))
a.head()
# Out:
#   market_name               market_title engine tradedate secid         value     volume  numtrades
# 0      shares                Рынок акций  stock      None  AFKS  3.382306e+07    2449200       1361
# 1         ndm  Режим переговорных сделок  stock      None  AFKS  1.393000e+04       1000          1
# 2        repo          Рынок сделок РЕПО  stock      None  AFKS  1.414133e+09  142343300         36

# %%
a = security_aggregates(random.choice(securityids), date=dt)
a.head()
# Out:
#   market_name               market_title engine   tradedate secid         value     volume  numtrades
# 0      shares                Рынок акций  stock  2017-09-11  AFKS  1.860079e+08   13583502       4879
# 1         ndm  Режим переговорных сделок  stock  2017-09-11  AFKS  1.014540e+05       7400          1
# 2        repo          Рынок сделок РЕПО  stock  2017-09-11  AFKS  1.086188e+09  108896200         57

# %%
by = security_bondyields(securityids[-1])
by.head()
# Out:
#     tradedate tradetime         secid boardid         name                                              title       value
# 0  2017-09-13  12:49:30  SU25081RMFS9    PSOB   CLOSEPRICE                              Цена последней сделки       99.35
# 1  2017-09-13  12:49:30  SU25081RMFS9    PSOB  TRADEMOMENT                        Дата/время последней сделки  2017-09-06
# 2  2017-09-13  12:49:30  SU25081RMFS9    PSOB        YIELD  Доходность для купонных облигаций с одним (пос...        8.21
# 3  2017-09-13  12:49:30  SU25081RMFS9    PTOB   CLOSEPRICE                              Цена последней сделки      99.395
# 4  2017-09-13  12:49:30  SU25081RMFS9    PTOB  TRADEMOMENT                        Дата/время последней сделки  2017-09-06

# %%
by = security_bondyields(securityids[-1], date=dt)
by.head()
# Out:
#     tradedate tradetime         secid boardid         name                                              title       value
# 0  2017-09-11  20:30:09  SU25081RMFS9    PSOB   CLOSEPRICE                              Цена последней сделки       99.35
# 1  2017-09-11  20:30:09  SU25081RMFS9    PSOB  TRADEMOMENT                        Дата/время последней сделки  2017-09-06
# 2  2017-09-11  20:30:09  SU25081RMFS9    PSOB        YIELD  Доходность для купонных облигаций с одним (пос...        8.09
# 3  2017-09-11  20:30:09  SU25081RMFS9    PTOB   CLOSEPRICE                              Цена последней сделки      99.395
# 4  2017-09-11  20:30:09  SU25081RMFS9    PTOB  TRADEMOMENT                        Дата/время последней сделки  2017-09-06
