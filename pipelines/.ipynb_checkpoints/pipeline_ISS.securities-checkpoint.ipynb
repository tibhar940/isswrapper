# %%
import pandas as pd
import datetime
import random
import os
import sys

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)

# %%
from ISS.securities import q, security_description, security_boards, security_indices, security_aggregates, security_bondyields

# %%
securityids = ['MOEX', 'SBER', 'AFKS', 'SU25081RMFS9']
dt = datetime.date(2017, 9, 11)

# %%
s = q(random.choice(securityids))
s.head()
# Out:
#        id  secid   shortname  regnumber                            name          isin  is_traded  emitent_id                                     emitent_title emitent_inn emitent_okpo     gosreg             type          group primary_boardid marketprice_boardid
# 0    5443   SBER    Сбербанк  10301481B          Сбербанк России ПАО ао  RU0009029540          1        1199  Публичное акционерное общество "Сбербанк России"  7707083893     00032537  10301481B     common_share   stock_shares            TQBR                TQBR
# 1    5444  SBERP  Сбербанк-п  20301481B          Сбербанк России ПАО ап  RU0009029557          1        1199  Публичное акционерное общество "Сбербанк России"  7707083893     00032537  20301481B  preferred_share   stock_shares            TQBR                TQBR
# 2  110765   SRU7   SBRF-9.17       None   Фьючерсный контракт SBRF-9.17          None          1        1199  Публичное акционерное общество "Сбербанк России"  7707083893     00032537       None          futures  futures_forts            RFUD                None
# 3  123326   SPU7   SBPR-9.17       None   Фьючерсный контракт SBPR-9.17          None          1        1199  Публичное акционерное общество "Сбербанк России"  7707083893     00032537       None          futures  futures_forts            RFUD                None
# 4  117178   SRZ7  SBRF-12.17       None  Фьючерсный контракт SBRF-12.17          None          1        1199  Публичное акционерное общество "Сбербанк России"  7707083893     00032537       None          futures  futures_forts            RFUD                None

# %%
d = security_description(random.choice(securityids))
d.head()
# Out:
#         name                              title                 value    type  sort_order  is_hidden  precision
# 0      SECID                  Код ценной бумаги                  MOEX  string           1          0        NaN
# 1       NAME                Полное наименование  ПАО Московская Биржа  string           2          0        NaN
# 2  SHORTNAME               Краткое наименование              МосБиржа  string           3          0        NaN
# 3       ISIN                           ISIN код          RU000A0JR4A1  string           4          0        NaN
# 4  REGNUMBER  Номер государственной регистрации          1-05-08443-H  string           5          0        NaN

# %%
b = security_boards(random.choice(securityids))
b.head()
# Out:
#           secid boardid                title  board_group_id  market_id market  engine_id engine  is_traded  decimals history_from history_till listed_from listed_till  is_primary
# 0  SU25081RMFS9    TQOB         Т+ Облигации              58          2  bonds          1  stock          1         4   2013-03-25   2017-09-12  2013-03-25  2017-09-13           1
# 1  SU25081RMFS9    EQOB         Т0 Облигации               7          2  bonds          1  stock          0         4   2013-02-06   2015-05-29  2013-02-06  2015-05-29           0
# 2  SU25081RMFS9    SPOB      Поставка по ОФЗ               7          2  bonds          1  stock          1         4   2013-09-05   2013-12-05  2013-09-05  2017-09-13           0
# 3  SU25081RMFS9    AUCT  Размещение: Аукцион               7          2  bonds          1  stock          0         4   2013-02-06   2013-10-30  2013-02-06  2013-10-30           0
# 4  SU25081RMFS9    SOTC   Внебиржевые сделки              71         29    otc          1  stock          0         5   2014-07-08   2017-09-12  2014-07-08  2017-09-13           0

# %%
i = security_indices(random.choice(securityids))
i.head()
# Out:
#           SECID      SHORTNAME        FROM        TILL
# 0  MICEX10INDEX        ММВБ 10  2016-01-12  2017-09-12
# 1      MICEXBMI  Широкий рынок  2013-03-18  2017-09-12
# 2      MICEXFNL        Финансы  2013-03-18  2017-09-12
# 3  MICEXINDEXCF    Индекс ММВБ  2013-03-18  2017-09-12
# 4       MICEXMC       MICEX MC  2013-04-25  2015-03-01

# %%
a = security_aggregates(random.choice(securityids))
a.head()
# Out:
#   market_name               market_title engine tradedate secid         value    volume  numtrades
# 0      shares                Рынок акций  stock      None  SBER  4.043706e+09  21301920      22424
# 1         ndm  Режим переговорных сделок  stock      None  SBER  4.300972e+07    225730         15
# 2         otc                        ОТС  stock      None  SBER  1.622899e+07     85510         58
# 3        repo          Рынок сделок РЕПО  stock      None  SBER  1.639134e+10  95394536        273

# %%
a = security_aggregates(random.choice(securityids), date=dt)
a.head()
# Out:
#   market_name               market_title engine   tradedate secid         value     volume  numtrades
# 0      shares                Рынок акций  stock  2017-09-11  SBER  1.168874e+10   61682326      77761
# 1         ndm  Режим переговорных сделок  stock  2017-09-11  SBER  9.324553e+07     489530         24
# 2        repo          Рынок сделок РЕПО  stock  2017-09-11  SBER  2.466393e+10  146179901        481

# %%
by = security_bondyields(securityids[-1])
by.head()
# Out:
#     tradedate tradetime         secid boardid         name                                              title       value
# 0  2017-09-13  13:09:05  SU25081RMFS9    PSOB   CLOSEPRICE                              Цена последней сделки       99.35
# 1  2017-09-13  13:09:05  SU25081RMFS9    PSOB  TRADEMOMENT                        Дата/время последней сделки  2017-09-06
# 2  2017-09-13  13:09:05  SU25081RMFS9    PSOB        YIELD  Доходность для купонных облигаций с одним (пос...        8.21
# 3  2017-09-13  13:09:05  SU25081RMFS9    PTOB   CLOSEPRICE                              Цена последней сделки      99.395
# 4  2017-09-13  13:09:05  SU25081RMFS9    PTOB  TRADEMOMENT                        Дата/время последней сделки  2017-09-06

# %%
by = security_bondyields(securityids[-1], date=dt)
by.head()
# Out:
#     tradedate tradetime         secid boardid         name                                              title       value
# 0  2017-09-11  20:30:09  SU25081RMFS9    PSOB   CLOSEPRICE                              Цена последней сделки       99.35
# 1  2017-09-11  20:30:09  SU25081RMFS9    PSOB  TRADEMOMENT                        Дата/время последней сделки  2017-09-06
# 2  2017-09-11  20:30:09  SU25081RMFS9    PSOB        YIELD  Доходность для купонных облигаций с одним (пос...        8.09
# 3  2017-09-11  20:30:09  SU25081RMFS9    PTOB   CLOSEPRICE                              Цена последней сделки      99.395
# 4  2017-09-11  20:30:09  SU25081RMFS9    PTOB  TRADEMOMENT                        Дата/время последней сделки  2017-09-06
